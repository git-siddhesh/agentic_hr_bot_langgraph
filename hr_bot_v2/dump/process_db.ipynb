# %%
import pandas as pd

# %%
import sqlite3

# %%
# read xlsx file
import pandas as pd
# Load all sheets into separate dataframes
sheets = pd.read_excel("hr_bot.xlsx", sheet_name=None)
dfs = {sheet_name: pd.DataFrame(data) for sheet_name, data in sheets.items()}
dfs.keys()
# Out:
# dict_keys(['paysheet', 'it reco', 'ctc reco', 'pf reco', 'master reco', 'other deduction', 'reimbursements', 'july reimbursements', 'aug reimbursements'])

# %%
dfs
# Out:
# {'paysheet':     Sl No.   Code             Name                  DOJ  Relieved Date  \
#  0      1.0    210       Aman Kumar  2017-01-04 00:00:00            NaN
#  1      2.0    211  Shiddhart Singh           21/02/2016            NaN
#  2      3.0    212             Amit  2018-01-03 00:00:00            NaN
#  3      4.0    213     Lokesh joshi  2022-01-04 00:00:00            NaN
#  4      5.0    214      Navin Kumar  2022-01-06 00:00:00            NaN
#  5      6.0    215             Jaya           25/07/2022            NaN
#  6      7.0    216         Devbrath           27/06/2022            NaN
#  7      8.0    217    Somesh Mishra           27/06/2022            NaN
#  8      9.0    218   Rishabh Pandey  2022-12-10 00:00:00            NaN
#  9     10.0    219       Ravi Kumar           21/04/2017            NaN
#  10    11.0    220  Saurabh Shekhar  2016-02-02 00:00:00            NaN
#  11    12.0    221         Shahid K  2018-09-03 00:00:00            NaN
# ...

# %%
# for each dfs 
# replace any value having '-' with 0 and convert to int

for key in dfs.keys():
    dfs[key] = dfs[key].replace('-', 0)


dfs
# Out:
# {'paysheet':     Sl No.   Code             Name                  DOJ  Relieved Date  \
#  0      1.0    210       Aman Kumar  2017-01-04 00:00:00            NaN
#  1      2.0    211  Shiddhart Singh           21/02/2016            NaN
#  2      3.0    212             Amit  2018-01-03 00:00:00            NaN
#  3      4.0    213     Lokesh joshi  2022-01-04 00:00:00            NaN
#  4      5.0    214      Navin Kumar  2022-01-06 00:00:00            NaN
#  5      6.0    215             Jaya           25/07/2022            NaN
#  6      7.0    216         Devbrath           27/06/2022            NaN
#  7      8.0    217    Somesh Mishra           27/06/2022            NaN
#  8      9.0    218   Rishabh Pandey  2022-12-10 00:00:00            NaN
#  9     10.0    219       Ravi Kumar           21/04/2017            NaN
#  10    11.0    220  Saurabh Shekhar  2016-02-02 00:00:00            NaN
#  11    12.0    221         Shahid K  2018-09-03 00:00:00            NaN
# ...

# %%
# Create a connection to the SQLite database
conn = sqlite3.connect('hr_bot.db')

# Iterate over the dfs dictionary and store each dataframe in the database
for sheet_name, df in dfs.items():
    df.to_sql(sheet_name.replace(' ', '_').lower()
              , conn, if_exists='replace', index=False)

# Commit the changes and close the connection
conn.commit()
conn.close()

# Create a connection to the SQLite database
conn = sqlite3.connect('hr_bot.db')
# fetch the data from the database using a SQL query
query = "SELECT * FROM 'paysheet'"
cursor = conn.cursor()
cursor.execute(query)
data = cursor.fetchall()
# Close the connection
conn.close()

data
# Out:
# [(1.0,
#   '210',
#   'Aman Kumar',
#   '2017-01-04 00:00:00',
#   None,
#   'Finance',
#   'Manager',
#   'ICICI Bank',
#   None,
#   'ICIC0000',
#   None,
#   31.0,
#   0.0,
#   0.0,
#   '20800',
#   '10400',
#   3333,
#   '10000',
#   0,
#   '44533',
#   '0',
#   None,
#   2496,
#   '2496',
#   '42037',
#   '5,04,444'),
#  (2.0,
#   '211',
#   'Shiddhart Singh',
#   '21/02/2016',
#   None,
#   'Finance',
#   'Senior Manager',
#   'ICICI Bank',
#   None,
#   'ICIC0000',
#   None,
#   31.0,
#   0.0,
#   0.0,
#   '20000',
#   '50000',
#   3333,
#   '32667',
#   0,
#   '1,06,000',
#   '27846',
#   None,
#   12000,
#   '39846',
#   '66154',
#   '7,93,848'),
#  (3.0,
#   '212',
#   'Amit',
#   '2018-01-03 00:00:00',
#   None,
#   'Finance',
#   'Director-Finance',
#   'ICICI Bank',
#   None,
#   'ICIC0000',
#   None,
#   31.0,
#   0.0,
#   0.0,
#   '2,10,000',
#   '65000',
#   3333,
#   '32467',
#   0,
#   '3,10,800',
#   '24196',
#   6000.0,
#   13200,
#   '43396',
#   '2,67,404',
# ...

# %%
# get the column names of the table 
conn = sqlite3.connect('hr_bot.db')
cursor = conn.cursor()
cursor.execute("PRAGMA table_info('paysheet')")
columns = cursor.fetchall()
cursor.close()
conn.close()
columns = [column[1] for column in columns]
columns
# Out:
# ['Sl No.',
#  'Code',
#  'Name',
#  'DOJ',
#  'Relieved Date',
#  'Department',
#  'Designation',
#  'Bank name',
#  'Bank Ac No',
#  'IFSC Code',
#  'Resigned Date',
#  'Emp Worked days',
#  'LOP Days',
#  'RLOP',
#  'BASIC',
#  'House Rent Allowance',
#  'Conveyance Allowance',
#  'Special Allowance',
#  'Field Expenses',
#  'Total Earnings',
#  'Income Tax',
#  'Other Deductions',
#  'Provident Fund',
#  'Total Deductions',
#  'NETPAY',
#  'Remarks']

# %%
# Create a connection to the SQLite database
conn = sqlite3.connect('hr_bot.db')
# fetch the data from the database using a SQL query
query = "SELECT * FROM 'paysheet' where Code == 210"
cursor = conn.cursor()
cursor.execute(query)
data = cursor.fetchall()
# Close the connection
cursor.close()
conn.close()

data
# Out:
# [(1.0,
#   '210',
#   'Aman Kumar',
#   '2017-01-04 00:00:00',
#   None,
#   'Finance',
#   'Manager',
#   'ICICI Bank',
#   None,
#   'ICIC0000',
#   None,
#   31.0,
#   0.0,
#   0.0,
#   '20800',
#   '10400',
#   3333,
#   '10000',
#   0,
#   '44533',
#   '0',
#   None,
#   2496,
#   '2496',
#   '42037',
#   '5,04,444')]

# %%
# Out:
# [('210',
#   'Manager',
#   'Finance',
#   '20800',
#   '10400',
#   3333,
#   '10000',
#   0,
#   '44533',
#   '0',
#   2496,
#   None,
#   '2496',
#   '42037',
#   '5,04,444')]

# %% [markdown]
#   Employee details:
#
#  'Code',
#  'Designation',
#  'Department',
#
#   Earnings:
#
#  'BASIC',
#  'House Rent Allowance',
#  'Conveyance Allowance',
#  'Special Allowance',
#  'Field Expenses',
#  'Total Earnings',
#
#   Deductions:
#
#  'Income Tax',
#  'Provident Fund',
#  'Other Deductions',
#  'Total Deductions',
#
#   Net Pay:
#
#  'NETPAY',
#
#  'Remarks'

# %%
import yaml
DB = yaml.safe_load(open("..\\files\\salary_data.yaml", "r"))
VARS = {}
for key, value in DB.items():
    for k, v in value['vars'].items():
        VARS[k] = v['use']


DB2 = yaml.safe_load(open("..\\files\\predefined_queries.yaml", "r"))
PREDEFINED_VARS  = {}
for key, value in DB2.items():
    PREDEFINED_VARS[key] = value['use']

# %%
VARS
# Out:
# {'DOJ': 'date of joining',
#  'Relieved Date': 'date of relieving',
#  'Department': 'department of the user (Sales, Finance, HR, etc)',
#  'Designation': 'designation of the user (Manager, Executive, Team Lead, Sr. Executive, etc)',
#  'Bank name': 'name of the bank (ICICI, HDFC, SBI, etc)',
#  'Bank Ac No': 'bank account number',
#  'IFSC EMP_ID': 'IFSC EMP_ID of the bank',
#  'Resigned Date': 'date of resignation',
#  'Emp Worked days': 'number of days worked by the user',
#  'LOP Days': 'number of days of leave without pay',
#  'RLOP': 'number of days of regular leave without pay',
#  'BASIC': 'basic salary of the employee',
#  'House Rent Allowance': 'house rent allowance provided to the employee',
#  'Conveyance Allowance': 'conveyance allowance provided to the employee',
#  'Special Allowance': 'special allowance given to the employee',
#  'Field Expenses': 'field expenses of the user',
#  'Total Earnings': 'total earnings for the employee in the given period',
# ...

# %%
PREDEFINED_VARS
# Out:
# {'paysheet': 'To returns the paysheet of an employee based on the employee code.\n'}

# %%
DB2['paysheet']['query']
# Out:
# 'SELECT  \nCode,\nDesignation, \nDepartment,\nBASIC,\n"House Rent Allowance",\n"Conveyance Allowance",\n"Special Allowance",\n"Field Expenses",\n"Total Earnings",\n"Income Tax",\n"Provident Fund",\n"Other Deductions",\n"Total Deductions",\n"NETPAY",\n"Remarks"\nFROM \'paysheet\' where Code == {code}\n'

# %%
DB2['paysheet']['input_params']
# Out:
# [{'code': {'type': 'string', 'description': 'Employee code'}}]

# %%
DB2['paysheet']['columns']
# Out:
# {'Code': 'Employee Code',
#  'Designation': 'Employee Designation',
#  'Department': 'Employee Department',
#  'BASIC': 'Basic Salary',
#  'House Rent Allowance': 'House Rent Allowance',
#  'Conveyance Allowance': 'Conveyance Allowance',
#  'Special Allowance': 'Special Allowance',
#  'Field Expenses': 'Field Expenses',
#  'Total Earnings': 'Total Earnings',
#  'Income Tax': 'Income Tax',
#  'Provident Fund': 'Provident Fund',
#  'Other Deductions': 'Other Deductions',
#  'Total Deductions': 'Total Deductions',
#  'NETPAY': 'Net Pay',
#  'Remarks': 'Remarks'}

# %%
s = """
### Role overview: 
As a professional sales agent assistant. You can answer questions by querying from a knowledge base but should refrain from using general knowledge. You cannot take any other actions like accessing account info, etc.  

---

### Entities to consider -
<ENTITIES_TO_CONSIDER>

---

### Funds to consider (canonical names with synonyms) -
- fund_refer: Liquid Plus
  (liquid plus fund, liquid plust debt fund), 
  "Assure" Fund, 
  Income Advantage Fund,
  Income Advantage Guaranteed Fund, 
  Protector Fund, 
  Builder Fund, 
  Balancer Fund,
  Enhancer Fund, 
  Creator Fund, 
  Magnifier Fund, 
  Maximiser Fund,
  Maximiser Guaranteed Fund, 
  Super 20 Fund, 
  Multiplier Fund, 
  Pure Equity Fund, 
  Value & Momentum Fund,
  Capped Nifty Index Fund, 
  MNC Fund, 
  Small Cap Fund, 
  ESG Fund, 
  Asset Allocation
  Fund, 
  Pension Nourish Fund, 
  Pension Growth Fund, 
  Pension Enrich Fund, 
  Platinum
  Premier Fund, 
  Platinum Advantage Fund, 
  Foresight 5 Pay Fund, 
  Titanium I Fund,
  Linked Discontinued Policy Fund, 
  Pension Discontinued Policy Fund

--- 

### Important instruction -

There are two different types of plans Generic vs Assured one. 
For example : 
ABSLI Assured Income Plus V13 -Policy Contract
ABSLI Assured Income Plus V13_Leaflet_Web Version
ABSLI-Assured-Income-Plus-V13
ABSLI-Childs-Future-Assured-Plan-Presentation
ABSLI-Childs-Future-Assured-Plan-Brochure

Please detect and specify only if the query is for assured one explicitly.

---

### Output Format -

{
  "user_message": "paraphrase last user message in context of the entire User-AI conversation",
  <ENTITIES> "fund_refer present": true if one or more "fund_refer"s are mentioned or referred in the user message otherwise false,
  "fund_refer": [referenced fund_refer entities (list full canonical names only, exactly as they appear above with proper capitalization, do not list synonyms in parentheses), empty list otherwise],
  "user_sentiment": "negative, neutral or positive",
  "think": "write a step by step plan how AI should respond to the last user message, including steps like look up knowledge, list items",
  "search_query": "write keyword based search query to look up necessary business related knowledge, if any",
  "show_transfer_to_human_button" : "true if user asked to call, chat, email, ticket, reach human customer support agent or user is unhappy",
  "is_chitchat": "say 'yes' if user question is not related to the business",
  "chitchat_response_to_user": "if chitchat, response chitchat message or ask for more information, if needed"
}

---

### Input -
  <TRANSCRIPT[1:4:1:1]>

---

### Output Instructions -
  Produce JSON only with {...} without any markdown or other formatting like ``` 

---

"""

d = {'s': s}
d
# Out:
# {'s': '\n### Role overview: \nAs a professional sales agent assistant. You can answer questions by querying from a knowledge base but should refrain from using general knowledge. You cannot take any other actions like accessing account info, etc.  \n\n---\n\n### Entities to consider -\n<ENTITIES_TO_CONSIDER>\n\n---\n\n### Funds to consider (canonical names with synonyms) -\n- fund_refer: Liquid Plus\n  (liquid plus fund, liquid plust debt fund), \n  "Assure" Fund, \n  Income Advantage Fund,\n  Income Advantage Guaranteed Fund, \n  Protector Fund, \n  Builder Fund, \n  Balancer Fund,\n  Enhancer Fund, \n  Creator Fund, \n  Magnifier Fund, \n  Maximiser Fund,\n  Maximiser Guaranteed Fund, \n  Super 20 Fund, \n  Multiplier Fund, \n  Pure Equity Fund, \n  Value & Momentum Fund,\n  Capped Nifty Index Fund, \n  MNC Fund, \n  Small Cap Fund, \n  ESG Fund, \n  Asset Allocation\n  Fund, \n  Pension Nourish Fund, \n  Pension Growth Fund, \n  Pension Enrich Fund, \n  Platinum\n  Premier Fund, \
# ...

# %%
import json 

# convert d to json
k = json.dumps(d)
k
# Out:
# '{"s": "\\n### Role overview: \\nAs a professional sales agent assistant. You can answer questions by querying from a knowledge base but should refrain from using general knowledge. You cannot take any other actions like accessing account info, etc.  \\n\\n---\\n\\n### Entities to consider -\\n<ENTITIES_TO_CONSIDER>\\n\\n---\\n\\n### Funds to consider (canonical names with synonyms) -\\n- fund_refer: Liquid Plus\\n  (liquid plus fund, liquid plust debt fund), \\n  \\"Assure\\" Fund, \\n  Income Advantage Fund,\\n  Income Advantage Guaranteed Fund, \\n  Protector Fund, \\n  Builder Fund, \\n  Balancer Fund,\\n  Enhancer Fund, \\n  Creator Fund, \\n  Magnifier Fund, \\n  Maximiser Fund,\\n  Maximiser Guaranteed Fund, \\n  Super 20 Fund, \\n  Multiplier Fund, \\n  Pure Equity Fund, \\n  Value & Momentum Fund,\\n  Capped Nifty Index Fund, \\n  MNC Fund, \\n  Small Cap Fund, \\n  ESG Fund, \\n  Asset Allocation\\n  Fund, \\n  Pension Nourish Fund, \\n  Pension Growth Fund, \\n  Pension En
# ...

# %%
j = json.loads(k)


# save the json to a file
with open('file.json', 'w') as f:
    json.dump(j, f)

# %%
f = json.loads(open('file.json').read())['prompt']
print(f)
# Out:
# context: "You are professional sales agent assistant. You can answer questions by\
#   \ querying from a knowledge base but should refrain from using general knowledge.\
#   \ You cannot take any other actions like accessing account info, etc.  \n\n<ENTITIES_TO_CONSIDER>\n\
#   \nFunds to consider (canonical names with synonyms) -\n- fund_refer: Liquid Plus\
#   \ (liquid plus fund, liquid plust debt fund), Assure Fund, Income Advantage Fund,\
#   \ Income Advantage Guaranteed Fund, Protector Fund, Builder Fund, Balancer Fund,\
#   \ Enhancer Fund, Creator Fund, Magnifier Fund, Maximiser Fund, Maximiser Guaranteed\
#   \ Fund, Super 20 Fund, Multiplier Fund, Pure Equity Fund, Value & Momentum Fund,\
#   \ Capped Nifty Index Fund, MNC Fund, Small Cap Fund, ESG Fund, Asset Allocation\
#   \ Fund, Pension Nourish Fund, Pension Growth Fund, Pension Enrich Fund, Platinum\
#   \ Premier Fund, Platinum Advantage Fund, Foresight 5 Pay Fund, Titanium I Fund,\
# ...

# %%
f2 = """context: "You are professional sales agent assistant. You can answer questions by
   querying from a knowledge base but should refrain from using general knowledge.
   You cannot take any other actions like accessing account info, etc.  <ENTITIES_TO_CONSIDER>
  Funds to consider (canonical names with synonyms) -- fund_refer: Liquid Plus
   (liquid plus fund, liquid plust debt fund), Assure Fund, Income Advantage Fund,
   Income Advantage Guaranteed Fund, Protector Fund, Builder Fund, Balancer Fund,
   Enhancer Fund, Creator Fund, Magnifier Fund, Maximiser Fund, Maximiser Guaranteed
   Fund, Super 20 Fund, Multiplier Fund, Pure Equity Fund, Value & Momentum Fund,
   Capped Nifty Index Fund, MNC Fund, Small Cap Fund, ESG Fund, Asset Allocation
   Fund, Pension Nourish Fund, Pension Growth Fund, Pension Enrich Fund, Platinum
   Premier Fund, Platinum Advantage Fund, Foresight 5 Pay Fund, Titanium I Fund,
   Linked Discontinued Policy Fund, Pension Discontinued Policy FundYou will
   produce JSON in the following format -{"user_message": "paraphrase last
   user message in context of the entire User-AI conversation",<ENTITIES>"
  fund_refer present": true if one or more "fund_refer"s are mentioned or referred
   in the user message otherwise false,"fund_refer": [referenced fund_refer entities
   (list full canonical names only, exactly as they appear above with proper capitalization,
   do not list synonyms in parentheses), empty list otherwise],"user_sentiment"
  : "negative, neutral or positive","think": "write a step by step plan how
   AI should respond to the last user message, including steps like look up knowledge,
   list items","search_query": "write keyword based search query to look up
   necessary business related knowledge, if any","show_transfer_to_human_button"
  : "true if user asked to call, chat, email, ticket, reach human customer support
   agent or user is unhappy","is_chitchat": "say 'yes' if user question is
   not related to the business","chitchat_response_to_user": "if chitchat,
   response chitchat message or ask for more information, if needed"}"
input: |-
  <TRANSCRIPT[1:4:1:1]>

  Produce JSON only.
  Begin!
"""

f2
# Out:
# 'context: "You are professional sales agent assistant. You can answer questions by\n   querying from a knowledge base but should refrain from using general knowledge.\n   You cannot take any other actions like accessing account info, etc.  <ENTITIES_TO_CONSIDER>\n  Funds to consider (canonical names with synonyms) -- fund_refer: Liquid Plus\n   (liquid plus fund, liquid plust debt fund), Assure Fund, Income Advantage Fund,\n   Income Advantage Guaranteed Fund, Protector Fund, Builder Fund, Balancer Fund,\n   Enhancer Fund, Creator Fund, Magnifier Fund, Maximiser Fund, Maximiser Guaranteed\n   Fund, Super 20 Fund, Multiplier Fund, Pure Equity Fund, Value & Momentum Fund,\n   Capped Nifty Index Fund, MNC Fund, Small Cap Fund, ESG Fund, Asset Allocation\n   Fund, Pension Nourish Fund, Pension Growth Fund, Pension Enrich Fund, Platinum\n   Premier Fund, Platinum Advantage Fund, Foresight 5 Pay Fund, Titanium I Fund,\n   Linked Discontinued Policy Fund, Pension Discontinued Policy FundYou
# ...

# %%
d2 = {'prompt': f2}
d2
# Out:
# {'prompt': 'context: "You are professional sales agent assistant. You can answer questions by\n   querying from a knowledge base but should refrain from using general knowledge.\n   You cannot take any other actions like accessing account info, etc.  <ENTITIES_TO_CONSIDER>\n  Funds to consider (canonical names with synonyms) -- fund_refer: Liquid Plus\n   (liquid plus fund, liquid plust debt fund), Assure Fund, Income Advantage Fund,\n   Income Advantage Guaranteed Fund, Protector Fund, Builder Fund, Balancer Fund,\n   Enhancer Fund, Creator Fund, Magnifier Fund, Maximiser Fund, Maximiser Guaranteed\n   Fund, Super 20 Fund, Multiplier Fund, Pure Equity Fund, Value & Momentum Fund,\n   Capped Nifty Index Fund, MNC Fund, Small Cap Fund, ESG Fund, Asset Allocation\n   Fund, Pension Nourish Fund, Pension Growth Fund, Pension Enrich Fund, Platinum\n   Premier Fund, Platinum Advantage Fund, Foresight 5 Pay Fund, Titanium I Fund,\n   Linked Discontinued Policy Fund, Pension Discontinued Pol
# ...

# %%
with open('file2.json', 'w') as f:
    json.dump(d2, f)

# %%
"""

### Input -
  <TRANSCRIPT[1:4:1:1]>

---

### Output Instructions -
  Produce JSON only with {...} without any markdown or other formatting like ``` 

---
"""

# %%
from functools import wraps
import queue
import sqlite3
from typing import Any, List, Tuple, Union, Dict
from sqlite3 import Connection


class DBPool:
    def __init__(self, minconn, maxconn, *args, **kwargs):
        self.minconn: int = minconn
        self.maxconn: int = maxconn
        self.args = args
        self.kwargs = kwargs
        self.pool = queue.Queue(maxsize=maxconn)
        for _ in range(minconn):
            self.pool.put(self.create_connection())

    def create_connection(self)-> Connection:
        # sqlite3 connection
        conn: Connection = sqlite3.connect('..\\files\\hr_bot.db')
        return conn

    def getconn(self) -> Connection:
        if self.pool.empty():
            if self.pool.qsize() < self.maxconn:
                self.pool.put(self.create_connection())
            else:
                raise Exception("Connection pool exhausted")
        return self.pool.get()

    def putconn(self, conn) -> None:
        self.pool.put(conn)


def db_connection(db_pool: DBPool | None):
    if db_pool is None:
        db_pool = DBPool(minconn=1, maxconn=5)

    def decorator(func):
        @wraps(wrapped=func)
        def wrapper(*args, **kwargs) -> Any:
            
            connection = None
            cursor = None
            try:
                connection = db_pool.getconn()
                print('Connected to PostgreSQL database successfully.')
                cursor = connection.cursor()
                result: Any = func(*args, cursor=cursor, **kwargs)
                connection.commit()
                return result
            except Exception as e:
                print(f"An unexpected error occurred: {e}")
                if connection:
                    connection.rollback()
                raise e
            finally:
                if cursor:
                    cursor.close()
                if connection:
                    db_pool.putconn(connection)

        return wrapper
    return decorator


db_pool = DBPool(minconn=1, maxconn=5)

@db_connection(db_pool)
def execute_query(query: str, args: Tuple, cursor) -> List[Union[Dict, Tuple]]:
    cursor.execute(query, args)
    columns = [col[0] for col in cursor.description]
    return [dict(zip(columns, row)) for row in cursor.fetchall()]


print(execute_query("SELECT * FROM paysheet WHERE Code = ?", args=("210",)))
# Out:
# Connected to PostgreSQL database successfully.
# [{'Sl No.': 1.0, 'Code': '210', 'Name': 'Aman Kumar', 'DOJ': '2017-01-04 00:00:00', 'Relieved Date': None, 'Department': 'Finance', 'Designation': 'Manager', 'Bank name': 'ICICI Bank', 'Bank Ac No': None, 'IFSC Code': 'ICIC0000', 'Resigned Date': None, 'Emp Worked days': 31.0, 'LOP Days': 0.0, 'RLOP': 0.0, 'BASIC': '20800', 'House Rent Allowance': '10400', 'Conveyance Allowance': 3333, 'Special Allowance': '10000', 'Field Expenses': 0, 'Total Earnings': '44533', 'Income Tax': '0', 'Other Deductions': None, 'Provident Fund': 2496, 'Total Deductions': '2496', 'NETPAY': '42037', 'Remarks': '5,04,444'}]
